# %%
# importing necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing data

# %%
data1=pd.read_csv('desktop/data.csv')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
# CRIM           506 non-null float64
# ZN             506 non-null float64
# INDUS          506 non-null float64
# CHAS           506 non-null int64
# NOX            506 non-null float64
# RM             506 non-null float64
# AGE            506 non-null float64
# DIS            506 non-null float64
# RAD            506 non-null int64
# TAX            506 non-null int64
# PTRAT          506 non-null float64
# B              506 non-null float64
# LSTAT          506 non-null float64
# MEDV           506 non-null float64
# Unnamed: 14    0 non-null float64
# Unnamed: 15    0 non-null float64
# Unnamed: 16    0 non-null float64
# dtypes: float64(14), int64(3)
# memory usage: 67.3 KB

# %%
# deleting the uncessary columns

# %%
data1.drop(["Unnamed: 14", "Unnamed: 15","Unnamed: 16"], axis = 1, inplace = True)

# %%
# checking the head,shape,info and description

# %%
data1.shape
# Out:
# (506, 14)

# %%
data1.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRAT  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296   15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242   17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242   17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222   18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222   18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM     506 non-null float64
# ZN       506 non-null float64
# INDUS    506 non-null float64
# CHAS     506 non-null int64
# NOX      506 non-null float64
# RM       506 non-null float64
# AGE      506 non-null float64
# DIS      506 non-null float64
# RAD      506 non-null int64
# TAX      506 non-null int64
# PTRAT    506 non-null float64
# B        506 non-null float64
# LSTAT    506 non-null float64
# MEDV     506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data1.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX       PTRAT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# creating corelational matrix

# %%
corrmatrix=data1.corr()
print(corrmatrix)
# Out:
#            CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM   1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN    -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS  -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX    0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM    -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE    0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS   -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD    0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX    0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRAT  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# creating a heatmap for corelational matrix

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corrmatrix,
           xticklabels=data1.columns,
           yticklabels=data1.columns,
           cmap='RdBu_r',
           annot=True,
           linewidth=0.5)

# %%
# histogram and density plot

# %%
for key,values in data1.iteritems():
    sns.distplot(data1[key])
    plt.show()

# %%
# box plot

# %%
for key,values in data1.iteritems():
    sns.boxplot(data1[key])
    plt.show()

# %%
# plots to be drawn with variable with close relationship

# %%
# crim plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='INDUS',y='CRIM',data=data1)
sns.scatterplot(x='INDUS',y='CRIM',data=data1)

# %%
sns.lmplot(x='INDUS',y='CRIM',data=data1)
sns.jointplot(x='INDUS',y='CRIM',data=data1,kind='kde')

# %%
sns.lineplot(x='NOX',y='CRIM',data=data1)
sns.scatterplot(x='NOX',y='CRIM',data=data1)

# %%
sns.lmplot(x='NOX',y='CRIM',data=data1)
sns.jointplot(x='NOX',y='CRIM',data=data1,kind='kde')

# %%
sns.lineplot(x='AGE',y='CRIM',data=data1)
sns.scatterplot(x='AGE',y='CRIM',data=data1)

# %%
sns.lmplot(x='AGE',y='CRIM',data=data1)
sns.jointplot(x='AGE',y='CRIM',data=data1,kind='kde')

# %%
sns.lineplot(x='RAD',y='CRIM',data=data1)
sns.scatterplot(x='RAD',y='CRIM',data=data1)

# %%
sns.lmplot(x='RAD',y='CRIM',data=data1)
sns.jointplot(x='AGE',y='CRIM',data=data1,kind='kde')

# %%
sns.lineplot(x='TAX',y='CRIM',data=data1)
sns.scatterplot(x='TAX',y='CRIM',data=data1)

# %%
sns.lmplot(x='TAX',y='CRIM',data=data1)
sns.jointplot(x='TAX',y='CRIM',data=data1,kind='kde')

# %%
sns.lineplot(x='PTRAT',y='CRIM',data=data1)
sns.scatterplot(x='PTRAT',y='CRIM',data=data1)

# %%
sns.lmplot(x='PTRAT',y='CRIM',data=data1)
sns.jointplot(x='PTRAT',y='CRIM',data=data1,kind='kde')

# %%
sns.lineplot(x='LSTAT',y='CRIM',data=data1)
sns.scatterplot(x='LSTAT',y='CRIM',data=data1)

# %%
sns.lmplot(x='LSTAT',y='CRIM',data=data1)
sns.jointplot(x='LSTAT',y='CRIM',data=data1,kind='kde')

# %%
# zn plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='ZN',y='RM',data=data1)
sns.scatterplot(x='ZN',y='RM',data=data1)

# %%
sns.lmplot(x='RM',y='ZN',data=data1)
sns.jointplot(x='RM',y='ZN',data=data1,kind='kde')

# %%
sns.lineplot(x='ZN',y='DIS',data=data1)
sns.scatterplot(x='ZN',y='DIS',data=data1)

# %%
sns.lmplot(x='ZN',y='DIS',data=data1)
sns.jointplot(x='ZN',y='DIS',data=data1,kind='kde')

# %%
# indus plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='INDUS',y='NOX',data=data1)
sns.scatterplot(x='INDUS',y='NOX',data=data1)

# %%
sns.lmplot(x='INDUS',y='NOX',data=data1)
sns.jointplot(x='INDUS',y='NOX',data=data1,kind='kde')

# %%
sns.lineplot(x='INDUS',y='AGE',data=data1)
sns.scatterplot(x='INDUS',y='AGE',data=data1)

# %%
sns.lmplot(x='INDUS',y='AGE',data=data1)
sns.jointplot(x='INDUS',y='AGE',data=data1,kind='kde')

# %%
sns.lineplot(x='RAD',y='INDUS',data=data1)
sns.scatterplot(x='RAD',y='INDUS',data=data1)

# %%
sns.lmplot(x='INDUS',y='RAD',data=data1)
sns.jointplot(x='INDUS',y='RAD',data=data1,kind='kde')

# %%
sns.lineplot(x='INDUS',y='TAX',data=data1)
sns.scatterplot(x='INDUS',y='TAX',data=data1)

# %%
sns.lmplot(x='INDUS',y='TAX',data=data1)
sns.jointplot(x='INDUS',y='TAX',data=data1,kind='kde')

# %%
sns.lineplot(x='PTRAT',y='INDUS',data=data1)
sns.scatterplot(x='PTRAT',y='INDUS',data=data1)

# %%
sns.lmplot(x='PTRAT',y='INDUS',data=data1)
sns.jointplot(x='PTRAT',y='INDUS',data=data1,kind='kde')

# %%
sns.lineplot(x='INDUS',y='LSTAT',data=data1)
sns.scatterplot(x='INDUS',y='LSTAT',data=data1)

# %%
sns.lmplot(x='INDUS',y='LSTAT',data=data1)
sns.jointplot(x='INDUS',y='LSTAT',data=data1,kind='kde')

# %%
# chas plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='CHAS',y='MEDV',data=data1)
sns.scatterplot(x='CHAS',y='MEDV',data=data1)

# %%
# nox plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='NOX',y='AGE',data=data1)
sns.scatterplot(x='NOX',y='AGE',data=data1)

# %%
sns.lmplot(x='NOX',y='AGE',data=data1)
sns.jointplot(x='NOX',y='AGE',data=data1,kind='kde')

# %%
sns.lineplot(x='RAD',y='NOX',data=data1)
sns.scatterplot(x='RAD',y='NOX',data=data1)

# %%
sns.lmplot(x='RAD',y='NOX',data=data1)
sns.jointplot(x='RAD',y='NOX',data=data1,kind='kde')

# %%
sns.lineplot(x='TAX',y='NOX',data=data1)
sns.scatterplot(x='TAX',y='NOX',data=data1)

# %%
sns.lmplot(x='TAX',y='NOX',data=data1)
sns.jointplot(x='TAX',y='NOX',data=data1,kind='kde')

# %%
sns.lineplot(x='NOX',y='LSTAT',data=data1)
sns.scatterplot(x='NOX',y='LSTAT',data=data1)

# %%
sns.lmplot(x='NOX',y='LSTAT',data=data1)
sns.jointplot(x='NOX',y='LSTAT',data=data1,kind='kde')

# %%
# rm plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='DIS',y='RM',data=data1)
sns.scatterplot(x='DIS',y='RM',data=data1)

# %%
sns.lmplot(x='DIS',y='RM',data=data1)
sns.jointplot(x='DIS',y='RM',data=data1,kind='kde')

# %%
sns.lineplot(x='B',y='RM',data=data1)
sns.scatterplot(x='B',y='RM',data=data1)

# %%
sns.lmplot(x='B',y='RM',data=data1)
sns.jointplot(x='B',y='RM',data=data1,kind='kde')

# %%
sns.lineplot(x='MEDV',y='RM',data=data1)
sns.scatterplot(x='MEDV',y='RM',data=data1)

# %%
sns.lmplot(x='MEDV',y='RM',data=data1)
sns.jointplot(x='MEDV',y='RM',data=data1,kind='kde')

# %%
sns.lineplot(x='RAD',y='AGE',data=data1)
sns.scatterplot(x='RAD',y='AGE',data=data1)

# %%
sns.lmplot(x='RAD',y='AGE',data=data1)
sns.jointplot(x='RAD',y='AGE',data=data1,kind='kde')

# %%
sns.lineplot(x='TAX',y='AGE',data=data1)
sns.scatterplot(x='TAX',y='AGE',data=data1)

# %%
sns.lmplot(x='TAX',y='AGE',data=data1)
sns.jointplot(x='TAX',y='AGE',data=data1,kind='kde')

# %%
sns.lineplot(x='PTRAT',y='AGE',data=data1)
sns.scatterplot(x='PTRAT',y='AGE',data=data1)

# %%
sns.lmplot(x='PTRAT',y='AGE',data=data1)
sns.jointplot(x='PTRAT',y='AGE',data=data1,kind='kde')

# %%
sns.lineplot(x='AGE',y='LSTAT',data=data1)
sns.scatterplot(x='AGE',y='LSTAT',data=data1)

# %%
sns.lmplot(x='AGE',y='LSTAT',data=data1)
sns.jointplot(x='AGE',y='LSTAT',data=data1,kind='kde')

# %%
# dis plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='B',y='DIS',data=data1)
sns.scatterplot(x='B',y='DIS',data=data1)

# %%
sns.lmplot(x='B',y='DIS',data=data1)
sns.jointplot(x='B',y='DIS',data=data1,kind='kde')

# %%
sns.lineplot(x='MEDV',y='DIS',data=data1)
sns.scatterplot(x='MEDV',y='DIS',data=data1)

# %%
sns.lmplot(x='MEDV',y='DIS',data=data1)
sns.jointplot(x='MEDV',y='DIS',data=data1,kind='kde')

# %%
# rad plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='RAD',y='TAX',data=data1)
sns.scatterplot(x='RAD',y='TAX',data=data1)

# %%
sns.lmplot(x='RAD',y='TAX',data=data1)
sns.jointplot(x='RAD',y='TAX',data=data1,kind='kde')

# %%
sns.lineplot(x='RAD',y='PTRAT',data=data1)
sns.scatterplot(x='RAD',y='PTRAT',data=data1)

# %%
sns.lmplot(x='RAD',y='PTRAT',data=data1)
sns.jointplot(x='RAD',y='PTRAT',data=data1,kind='kde')

# %%
sns.lineplot(x='RAD',y='LSTAT',data=data1)
sns.scatterplot(x='RAD',y='LSTAT',data=data1)

# %%
sns.lmplot(x='RAD',y='LSTAT',data=data1)
sns.jointplot(x='RAD',y='LSTAT',data=data1,kind='kde')

# %%
# tax plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='PTRAT',y='TAX',data=data1)
sns.scatterplot(x='PTRAT',y='TAX',data=data1)

# %%
sns.lmplot(x='PTRAT',y='TAX',data=data1)
sns.jointplot(x='PTRAT',y='TAX',data=data1,kind='kde')

# %%
sns.lineplot(x='TAX',y='LSTAT',data=data1)
sns.scatterplot(x='TAX',y='LSTAT',data=data1)

# %%
sns.lmplot(x='TAX',y='LSTAT',data=data1)
sns.jointplot(x='TAX',y='LSTAT',data=data1,kind='kde')

# %%
# ptrat plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='PTRAT',y='LSTAT',data=data1)
sns.scatterplot(x='PTRAT',y='LSTAT',data=data1)

# %%
sns.lmplot(x='PTRAT',y='LSTAT',data=data1)
sns.jointplot(x='PTRAT',y='LSTAT',data=data1,kind='kde')

# %%
# medv plots with varialbes which are closely related with corelational matrix

# %%
sns.lineplot(x='B',y='MEDV',data=data1)
sns.scatterplot(x='B',y='MEDV',data=data1)

# %%
sns.lmplot(x='B',y='MEDV',data=data1)
sns.jointplot(x='B',y='MEDV',data=data1,kind='kde')
